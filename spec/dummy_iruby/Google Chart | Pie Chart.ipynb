# %%
require 'daru/view'
# Out:
# Install the spreadsheet gem version ~>1.1.1 for using spreadsheet functions.
#
# Install the mechanize gem version ~>2.7.5 for using mechanize functions.
# true

# %%
Daru::View.plotting_library = :googlecharts
# Out:
# "\n   /* BEGIN google_visualr.js */\n\nif(!window['googleLT_']){window['googleLT_']=(new Date()).getTime();}if (!window['google']) {\nwindow['google'] = {};\n}\nif (!window['google']['loader']) {\nwindow['google']['loader'] = {};\ngoogle.loader.ServiceBase = 'https://www.google.com/uds';\ngoogle.loader.GoogleApisBase = 'https://ajax.googleapis.com/ajax';\ngoogle.loader.ApiKey = 'notsupplied';\ngoogle.loader.KeyVerified = true;\ngoogle.loader.LoadFailure = false;\ngoogle.loader.Secure = true;\ngoogle.loader.GoogleLocale = 'www.google.com';\ngoogle.loader.ClientLocation = null;\ngoogle.loader.AdditionalParams = '';\n(function() {function g(a){return a in l?l[a]:l[a]=-1!=navigator.userAgent.toLowerCase().indexOf(a)}var l={};function m(a,b){var c=function(){};c.prototype=b.prototype;a.ca=b.prototype;a.prototype=new c}function n(a,b,c){var d=Array.prototype.slice.call(arguments,2)||[];return function(){return a.apply(b,d.concat(Array.prototype.slice.call(arguments)))}}function p(a){a=Error(a);a.toString=function(){return this.message};return a}\nfunction q(a,b){a=a.split(/\\./);for(var c=window,d=0;d<a.length-1;d++)c[a[d]]||(c[a[d]]={}),c=c[a[d]];c[a[a.length-1]]=b}function r(a,b,c){a[b]=c}if(!t)var t=q;if(!u)var u=r;google.loader.F={};t(\"google.loader.callbacks\",google.loader.F);var v={},w={};google.loader.eval={};t(\"google.loader.eval\",google.loader.eval);\ngoogle.load=function(a,b,c){function d(a){var b=a.split(\".\");if(2<b.length)throw p(\"Module: '\"+a+\"' not found!\");\"undefined\"!=typeof b[1]&&(e=b[0],c.packages=c.packages||[],c.packages.push(b[1]))}var e=a;c=c||{};if(a instanceof Array||a&&\"object\"==typeof a&&\"function\"==typeof a.join&&\"function\"==typeof a.reverse)for(var f=0;f<a.length;f++)d(a[f]);else d(a);if(a=v[\":\"+e]){c&&!c.language&&c.locale&&(c.language=c.locale);c&&\"string\"==typeof c.callback&&(f=c.callback,f.match(/^[[\\]A-Za-z0-9._]+$/)&&(f=\nwindow.eval(f),c.callback=f));if((f=c&&null!=c.callback)&&!a.D(b))throw p(\"Module: '\"+e+\"' must be loaded before DOM onLoad!\");f?a.u(b,c)?window.setTimeout(c.callback,0):a.load(b,c):a.u(b,c)||a.load(b,c)}else throw p(\"Module: '\"+e+\"' not found!\");};t(\"google.load\",google.load);\ngoogle.ba=function(a,b){b?(0==x.length&&(y(window,\"load\",z),!g(\"msie\")&&!g(\"safari\")&&!g(\"konqueror\")&&g(\"mozilla\")||window.opera?window.addEventListener(\"DOMContentLoaded\",z,!1):g(\"msie\")?document.write(\"<script defer onreadystatechange='google.loader.domReady()' src=//:>\\x3c/script>\"):(g(\"safari\")||g(\"konqueror\"))&&window.setTimeout(B,10)),x.push(a)):y(window,\"load\",a)};t(\"google.setOnLoadCallback\",google.ba);\nfunction y(a,b,c){if(a.addEventListener)a.addEventListener(b,c,!1);else if(a.attachEvent)a.attachEvent(\"on\"+b,c);else{var d=a[\"on\"+b];a[\"on\"+b]=null!=d?C([c,d]):c}}function C(a){return function(){for(var b=0;b<a.length;b++)a[b]()}}var x=[];google.loader.W=function(){var a=window.event.srcElement;\"complete\"==a.readyState&&(a.onreadystatechange=null,a.parentNode.removeChild(a),z())};t(\"google.loader.domReady\",google.loader.W);var D={loaded:!0,complete:!0};\nfunction B(){D[document.readyState]?z():0<x.length&&window.setTimeout(B,10)}function z(){for(var a=0;a<x.length;a++)x[a]();x.length=0}\ngoogle.loader.f=function(a,b,c){if(c){if(\"script\"==a){var d=document.createElement(\"script\");d.type=\"text/javascript\";d.src=b}else\"css\"==a&&(d=document.createElement(\"link\"),d.type=\"text/css\",d.href=b,d.rel=\"stylesheet\");(a=document.getElementsByTagName(\"head\")[0])||(a=document.body.parentNode.appendChild(document.createElement(\"head\")));a.appendChild(d)}else\"script\"==a?document.write('<script src=\"'+b+'\" type=\"text/javascript\">\\x3c/script>'):\"css\"==a&&document.write('<link href=\"'+b+'\" type=\"text/css\" rel=\"stylesheet\"></link>')};\nt(\"google.loader.writeLoadTag\",google.loader.f);google.loader.Z=function(a){w=a};t(\"google.loader.rfm\",google.loader.Z);google.loader.aa=function(a){for(var b in a)\"string\"==typeof ...
# :googlecharts

# %%
data = [
          ['Task', 'Hours per Day'],
          ['Work',     11],
          ['Eat',      2],
          ['Commute',  2],
          ['Watch TV', 2],
          ['Sleep',    7]
  ]
pie_chart_table = Daru::View::Table.new(data)
pie_chart_table.show_in_iruby
# Out:
# "<div id='f4439f89-4ab5-406f-8f52-ec7b883232c7'></div>\n<script>\n\n  google.load('visualization', 1.0, \n {packages: ['table'], callback:\n draw_f4439f89_4ab5_406f_8f52_ec7b883232c7});\n  function draw_f4439f89_4ab5_406f_8f52_ec7b883232c7() {\n    var data_table = new google.visualization.DataTable();data_table.addColumn({\"type\":\"string\",\"label\":\"Task\"});data_table.addColumn({\"type\":\"number\",\"label\":\"Hours per Day\"});data_table.addRow([{v: \"Work\"}, {v: 11}]);data_table.addRow([{v: \"Eat\"}, {v: 2}]);data_table.addRow([{v: \"Commute\"}, {v: 2}]);data_table.addRow([{v: \"Watch TV\"}, {v: 2}]);data_table.addRow([{v: \"Sleep\"}, {v: 7}]);\n    var table = new google.visualization.Table(\n    document.getElementById('f4439f89-4ab5-406f-8f52-ec7b883232c7'));\n    table.draw(data_table, {}); \n  };\n</script>\n"

# %%
pie_chart_options = {
  type: :pie, height: 400,  title: 'My Daily Activities'
}
pie_chart_chart = Daru::View::Plot.new(pie_chart_table.table, pie_chart_options)
pie_chart_chart.show_in_iruby
# Out:
# "<div id='e80a5112-7ec9-4316-b7d4-23947c55299b'></div>\n<script>\n\n  google.load('visualization', '1.0', {packages: ['corechart'], callback: draw_e80a5112_7ec9_4316_b7d4_23947c55299b});\n  function draw_e80a5112_7ec9_4316_b7d4_23947c55299b() {\n    var data_table = new google.visualization.DataTable();data_table.addColumn({\"type\":\"string\",\"label\":\"Task\"});data_table.addColumn({\"type\":\"number\",\"label\":\"Hours per Day\"});data_table.addRow([{v: \"Work\"}, {v: 11}]);data_table.addRow([{v: \"Eat\"}, {v: 2}]);data_table.addRow([{v: \"Commute\"}, {v: 2}]);data_table.addRow([{v: \"Watch TV\"}, {v: 2}]);data_table.addRow([{v: \"Sleep\"}, {v: 7}]);\n    var chart = new google.visualization.PieChart(document.getElementById('e80a5112-7ec9-4316-b7d4-23947c55299b'));\n    chart.draw(data_table, {height: 400, title: \"My Daily Activities\"});\n  };\n</script>\n"

# %%
pie_chart3D_options = {
  type: :pie, height: 400,  title: 'My Daily Activities', is3D: true
}
pie_chart3D = Daru::View::Plot.new(pie_chart_table.table, pie_chart3D_options)
pie_chart3D.show_in_iruby
# Out:
# "<div id='f763705a-9b8a-449e-b089-353ce97cdd53'></div>\n<script>\n\n  google.load('visualization', '1.0', {packages: ['corechart'], callback: draw_f763705a_9b8a_449e_b089_353ce97cdd53});\n  function draw_f763705a_9b8a_449e_b089_353ce97cdd53() {\n    var data_table = new google.visualization.DataTable();data_table.addColumn({\"type\":\"string\",\"label\":\"Task\"});data_table.addColumn({\"type\":\"number\",\"label\":\"Hours per Day\"});data_table.addRow([{v: \"Work\"}, {v: 11}]);data_table.addRow([{v: \"Eat\"}, {v: 2}]);data_table.addRow([{v: \"Commute\"}, {v: 2}]);data_table.addRow([{v: \"Watch TV\"}, {v: 2}]);data_table.addRow([{v: \"Sleep\"}, {v: 7}]);\n    var chart = new google.visualization.PieChart(document.getElementById('f763705a-9b8a-449e-b089-353ce97cdd53'));\n    chart.draw(data_table, {height: 400, title: \"My Daily Activities\", is3D: true});\n  };\n</script>\n"

# %% [markdown]
# ### Making a Donut Chart

# %%
pie_chart_dount_options = {
  type: :pie, height: 400,  title: 'My Daily Activities',pieHole: 0.4,
}
pie_chart_dount = Daru::View::Plot.new(pie_chart_table.table, pie_chart_dount_options)
pie_chart_dount.show_in_iruby
# Out:
# "<div id='ab349652-d0db-4277-bff7-077760d20b61'></div>\n<script>\n\n  google.load('visualization', '1.0', {packages: ['corechart'], callback: draw_ab349652_d0db_4277_bff7_077760d20b61});\n  function draw_ab349652_d0db_4277_bff7_077760d20b61() {\n    var data_table = new google.visualization.DataTable();data_table.addColumn({\"type\":\"string\",\"label\":\"Task\"});data_table.addColumn({\"type\":\"number\",\"label\":\"Hours per Day\"});data_table.addRow([{v: \"Work\"}, {v: 11}]);data_table.addRow([{v: \"Eat\"}, {v: 2}]);data_table.addRow([{v: \"Commute\"}, {v: 2}]);data_table.addRow([{v: \"Watch TV\"}, {v: 2}]);data_table.addRow([{v: \"Sleep\"}, {v: 7}]);\n    var chart = new google.visualization.PieChart(document.getElementById('ab349652-d0db-4277-bff7-077760d20b61'));\n    chart.draw(data_table, {height: 400, title: \"My Daily Activities\", pieHole: 0.4});\n  };\n</script>\n"

# %%
pie_chart_dount_options = {
  type: :pie, height: 400,  title: 'My Daily Activities',pieHole: 0.5,
          pieSliceTextStyle: {
            color: 'black',
          },
          legend: 'none'
}
pie_chart_dount = Daru::View::Plot.new(pie_chart_table.table, pie_chart_dount_options)
pie_chart_dount.show_in_iruby
# Out:
# "<div id='b2474945-e334-4136-a7c1-3bc7acabb435'></div>\n<script>\n\n  google.load('visualization', '1.0', {packages: ['corechart'], callback: draw_b2474945_e334_4136_a7c1_3bc7acabb435});\n  function draw_b2474945_e334_4136_a7c1_3bc7acabb435() {\n    var data_table = new google.visualization.DataTable();data_table.addColumn({\"type\":\"string\",\"label\":\"Task\"});data_table.addColumn({\"type\":\"number\",\"label\":\"Hours per Day\"});data_table.addRow([{v: \"Work\"}, {v: 11}]);data_table.addRow([{v: \"Eat\"}, {v: 2}]);data_table.addRow([{v: \"Commute\"}, {v: 2}]);data_table.addRow([{v: \"Watch TV\"}, {v: 2}]);data_table.addRow([{v: \"Sleep\"}, {v: 7}]);\n    var chart = new google.visualization.PieChart(document.getElementById('b2474945-e334-4136-a7c1-3bc7acabb435'));\n    chart.draw(data_table, {height: 400, title: \"My Daily Activities\", pieHole: 0.5, pieSliceTextStyle: {color: \"black\"}, legend: \"none\"});\n  };\n</script>\n"

# %% [markdown]
# ### Rotating a Pie Chart

# %%
data = [
          ['Language', 'Speakers (in millions)'],
          ['German',  5.85],
          ['French',  1.66],
          ['Italian', 0.316],
          ['Romansh', 0.0791]
  ]
pie_chart_rotate_table = Daru::View::Table.new(data)
pie_chart_rotate_table.show_in_iruby
# Out:
# "<div id='37847f63-f266-4a40-bf8a-bc37c89f1b48'></div>\n<script>\n\n  google.load('visualization', 1.0, \n {packages: ['table'], callback:\n draw_37847f63_f266_4a40_bf8a_bc37c89f1b48});\n  function draw_37847f63_f266_4a40_bf8a_bc37c89f1b48() {\n    var data_table = new google.visualization.DataTable();data_table.addColumn({\"type\":\"string\",\"label\":\"Language\"});data_table.addColumn({\"type\":\"number\",\"label\":\"Speakers (in millions)\"});data_table.addRow([{v: \"German\"}, {v: 5.85}]);data_table.addRow([{v: \"French\"}, {v: 1.66}]);data_table.addRow([{v: \"Italian\"}, {v: 0.316}]);data_table.addRow([{v: \"Romansh\"}, {v: 0.0791}]);\n    var table = new google.visualization.Table(\n    document.getElementById('37847f63-f266-4a40-bf8a-bc37c89f1b48'));\n    table.draw(data_table, {}); \n  };\n</script>\n"

# %%
pie_chart_rotate_options = {
type: :pie, height: 500
}
pie_chart_rotate_dount = Daru::View::Plot.new(pie_chart_rotate_table.table, pie_chart_rotate_options)
pie_chart_rotate_dount.show_in_iruby
# Out:
# "<div id='036d9a05-010f-406f-a3cc-e45590d4b1ec'></div>\n<script>\n\n  google.load('visualization', '1.0', {packages: ['corechart'], callback: draw_036d9a05_010f_406f_a3cc_e45590d4b1ec});\n  function draw_036d9a05_010f_406f_a3cc_e45590d4b1ec() {\n    var data_table = new google.visualization.DataTable();data_table.addColumn({\"type\":\"string\",\"label\":\"Language\"});data_table.addColumn({\"type\":\"number\",\"label\":\"Speakers (in millions)\"});data_table.addRow([{v: \"German\"}, {v: 5.85}]);data_table.addRow([{v: \"French\"}, {v: 1.66}]);data_table.addRow([{v: \"Italian\"}, {v: 0.316}]);data_table.addRow([{v: \"Romansh\"}, {v: 0.0791}]);\n    var chart = new google.visualization.PieChart(document.getElementById('036d9a05-010f-406f-a3cc-e45590d4b1ec'));\n    chart.draw(data_table, {height: 500});\n  };\n</script>\n"

# %%
pie_chart_rotate_options = {
  legend: 'none',
        pieSliceText: 'label',
        title: 'Swiss Language Use (100 degree rotation)',
        pieStartAngle: 100,type: :pie, height: 500
}
pie_chart_rotate_dount = Daru::View::Plot.new(pie_chart_rotate_table.table, pie_chart_rotate_options)
pie_chart_rotate_dount.show_in_iruby
# Out:
# "<div id='d8b566df-6f07-4cd2-8270-36d877fad332'></div>\n<script>\n\n  google.load('visualization', '1.0', {packages: ['corechart'], callback: draw_d8b566df_6f07_4cd2_8270_36d877fad332});\n  function draw_d8b566df_6f07_4cd2_8270_36d877fad332() {\n    var data_table = new google.visualization.DataTable();data_table.addColumn({\"type\":\"string\",\"label\":\"Language\"});data_table.addColumn({\"type\":\"number\",\"label\":\"Speakers (in millions)\"});data_table.addRow([{v: \"German\"}, {v: 5.85}]);data_table.addRow([{v: \"French\"}, {v: 1.66}]);data_table.addRow([{v: \"Italian\"}, {v: 0.316}]);data_table.addRow([{v: \"Romansh\"}, {v: 0.0791}]);\n    var chart = new google.visualization.PieChart(document.getElementById('d8b566df-6f07-4cd2-8270-36d877fad332'));\n    chart.draw(data_table, {legend: \"none\", pieSliceText: \"label\", title: \"Swiss Language Use (100 degree rotation)\", pieStartAngle: 100, height: 500});\n  };\n</script>\n"

# %% [markdown]
# ### Exploding a Slice

# %%
data = [
          ['Language', 'Speakers (in millions)'],
          ['Assamese', 13], ['Bengali', 83], ['Bodo', 1.4],
          ['Dogri', 2.3], ['Gujarati', 46], ['Hindi', 300],
          ['Kannada', 38], ['Kashmiri', 5.5], ['Konkani', 5],
          ['Maithili', 20], ['Malayalam', 33], ['Manipuri', 1.5],
          ['Marathi', 72], ['Nepali', 2.9], ['Oriya', 33],
          ['Punjabi', 29], ['Sanskrit', 0.01], ['Santhali', 6.5],
          ['Sindhi', 2.5], ['Tamil', 61], ['Telugu', 74], ['Urdu', 52]
  ]
pie_chart_slice_table = Daru::View::Table.new(data, pageSize: 5)
pie_chart_slice_table.show_in_iruby
# Out:
# "<div id='07994194-75ad-49e4-aa80-b0cbe1ecfded'></div>\n<script>\n\n  google.load('visualization', 1.0, \n {packages: ['table'], callback:\n draw_07994194_75ad_49e4_aa80_b0cbe1ecfded});\n  function draw_07994194_75ad_49e4_aa80_b0cbe1ecfded() {\n    var data_table = new google.visualization.DataTable();data_table.addColumn({\"type\":\"string\",\"label\":\"Language\"});data_table.addColumn({\"type\":\"number\",\"label\":\"Speakers (in millions)\"});data_table.addRow([{v: \"Assamese\"}, {v: 13}]);data_table.addRow([{v: \"Bengali\"}, {v: 83}]);data_table.addRow([{v: \"Bodo\"}, {v: 1.4}]);data_table.addRow([{v: \"Dogri\"}, {v: 2.3}]);data_table.addRow([{v: \"Gujarati\"}, {v: 46}]);data_table.addRow([{v: \"Hindi\"}, {v: 300}]);data_table.addRow([{v: \"Kannada\"}, {v: 38}]);data_table.addRow([{v: \"Kashmiri\"}, {v: 5.5}]);data_table.addRow([{v: \"Konkani\"}, {v: 5}]);data_table.addRow([{v: \"Maithili\"}, {v: 20}]);data_table.addRow([{v: \"Malayalam\"}, {v: 33}]);data_table.addRow([{v: \"Manipuri\"}, {v: 1.5}]);data_table.addRow([{v: \"Marathi\"}, {v: 72}]);data_table.addRow([{v: \"Nepali\"}, {v: 2.9}]);data_table.addRow([{v: \"Oriya\"}, {v: 33}]);data_table.addRow([{v: \"Punjabi\"}, {v: 29}]);data_table.addRow([{v: \"Sanskrit\"}, {v: 0.01}]);data_table.addRow([{v: \"Santhali\"}, {v: 6.5}]);data_table.addRow([{v: \"Sindhi\"}, {v: 2.5}]);data_table.addRow([{v: \"Tamil\"}, {v: 61}]);data_table.addRow([{v: \"Telugu\"}, {v: 74}]);data_table.addRow([{v: \"Urdu\"}, {v: 52}]);\n    var table = new google.visualization.Table(\n    document.getElementById('07994194-75ad-49e4-aa80-b0cbe1ecfded'));\n    table.draw(data_table, {pageSize: 5}); \n  };\n</script>\n"

# %%
pie_chart_slice_options = {
type: :pie, height: 500
}
pie_chart_slice = Daru::View::Plot.new(pie_chart_slice_table.table, pie_chart_slice_options)
pie_chart_slice.show_in_iruby
# Out:
# "<div id='68f4f7c4-f2de-4f54-b6db-f03195f133f8'></div>\n<script>\n\n  google.load('visualization', '1.0', {packages: ['corechart'], callback: draw_68f4f7c4_f2de_4f54_b6db_f03195f133f8});\n  function draw_68f4f7c4_f2de_4f54_b6db_f03195f133f8() {\n    var data_table = new google.visualization.DataTable();data_table.addColumn({\"type\":\"string\",\"label\":\"Language\"});data_table.addColumn({\"type\":\"number\",\"label\":\"Speakers (in millions)\"});data_table.addRow([{v: \"Assamese\"}, {v: 13}]);data_table.addRow([{v: \"Bengali\"}, {v: 83}]);data_table.addRow([{v: \"Bodo\"}, {v: 1.4}]);data_table.addRow([{v: \"Dogri\"}, {v: 2.3}]);data_table.addRow([{v: \"Gujarati\"}, {v: 46}]);data_table.addRow([{v: \"Hindi\"}, {v: 300}]);data_table.addRow([{v: \"Kannada\"}, {v: 38}]);data_table.addRow([{v: \"Kashmiri\"}, {v: 5.5}]);data_table.addRow([{v: \"Konkani\"}, {v: 5}]);data_table.addRow([{v: \"Maithili\"}, {v: 20}]);data_table.addRow([{v: \"Malayalam\"}, {v: 33}]);data_table.addRow([{v: \"Manipuri\"}, {v: 1.5}]);data_table.addRow([{v: \"Marathi\"}, {v: 72}]);data_table.addRow([{v: \"Nepali\"}, {v: 2.9}]);data_table.addRow([{v: \"Oriya\"}, {v: 33}]);data_table.addRow([{v: \"Punjabi\"}, {v: 29}]);data_table.addRow([{v: \"Sanskrit\"}, {v: 0.01}]);data_table.addRow([{v: \"Santhali\"}, {v: 6.5}]);data_table.addRow([{v: \"Sindhi\"}, {v: 2.5}]);data_table.addRow([{v: \"Tamil\"}, {v: 61}]);data_table.addRow([{v: \"Telugu\"}, {v: 74}]);data_table.addRow([{v: \"Urdu\"}, {v: 52}]);\n    var chart = new google.visualization.PieChart(document.getElementById('68f4f7c4-f2de-4f54-b6db-f03195f133f8'));\n    chart.draw(data_table, {height: 500});\n  };\n</script>\n"

# %%
pie_chart_slice_options = {
  title: 'Indian Language Use',
          legend: 'none',
          pieSliceText: 'label',
          slices: {  4 => {offset: 0.2},
                    12 => {offset: 0.3},
                    14 => {offset: 0.4},
                    15 => {offset: 0.5},
          },
        type: :pie, height: 500
}
pie_chart_slice = Daru::View::Plot.new(pie_chart_slice_table.table, pie_chart_slice_options)
pie_chart_slice.show_in_iruby
# Out:
# "<div id='25c272c1-a5cc-417a-89ff-f02819fd2096'></div>\n<script>\n\n  google.load('visualization', '1.0', {packages: ['corechart'], callback: draw_25c272c1_a5cc_417a_89ff_f02819fd2096});\n  function draw_25c272c1_a5cc_417a_89ff_f02819fd2096() {\n    var data_table = new google.visualization.DataTable();data_table.addColumn({\"type\":\"string\",\"label\":\"Language\"});data_table.addColumn({\"type\":\"number\",\"label\":\"Speakers (in millions)\"});data_table.addRow([{v: \"Assamese\"}, {v: 13}]);data_table.addRow([{v: \"Bengali\"}, {v: 83}]);data_table.addRow([{v: \"Bodo\"}, {v: 1.4}]);data_table.addRow([{v: \"Dogri\"}, {v: 2.3}]);data_table.addRow([{v: \"Gujarati\"}, {v: 46}]);data_table.addRow([{v: \"Hindi\"}, {v: 300}]);data_table.addRow([{v: \"Kannada\"}, {v: 38}]);data_table.addRow([{v: \"Kashmiri\"}, {v: 5.5}]);data_table.addRow([{v: \"Konkani\"}, {v: 5}]);data_table.addRow([{v: \"Maithili\"}, {v: 20}]);data_table.addRow([{v: \"Malayalam\"}, {v: 33}]);data_table.addRow([{v: \"Manipuri\"}, {v: 1.5}]);data_table.addRow([{v: \"Marathi\"}, {v: 72}]);data_table.addRow([{v: \"Nepali\"}, {v: 2.9}]);data_table.addRow([{v: \"Oriya\"}, {v: 33}]);data_table.addRow([{v: \"Punjabi\"}, {v: 29}]);data_table.addRow([{v: \"Sanskrit\"}, {v: 0.01}]);data_table.addRow([{v: \"Santhali\"}, {v: 6.5}]);data_table.addRow([{v: \"Sindhi\"}, {v: 2.5}]);data_table.addRow([{v: \"Tamil\"}, {v: 61}]);data_table.addRow([{v: \"Telugu\"}, {v: 74}]);data_table.addRow([{v: \"Urdu\"}, {v: 52}]);\n    var chart = new google.visualization.PieChart(document.getElementById('25c272c1-a5cc-417a-89ff-f02819fd2096'));\n    chart.draw(data_table, {title: \"Indian Language Use\", legend: \"none\", pieSliceText: \"label\", slices: {4: {offset: 0.2}, 12: {offset: 0.3}, 14: {offset: 0.4}, 15: {offset: 0.5}}, height: 500});\n  };\n</script>\n"

# %% [markdown]
# ### Removing Slices

# %%
idx = Daru::Index.new ['Pac Man', 'Percentage']
data_rows = [
          ['', 75],
          ['', 25]]
df_pac_man = Daru::DataFrame.rows(data_rows)
df_pac_man.vectors = idx
df_pac_man
# Out:
# #<Daru::DataFrame(2x2)>
#                Pac Man Percentage
#           0                    75
#           1                    25

# %%
pie_pac_chart = Daru::View::Plot.new(df_pac_man, type: :pie)
pie_pac_chart.show_in_iruby
# Out:
# "<div id='c7a7044d-6b17-40f2-93aa-452a3ee09ece'></div>\n<script>\n\n  google.load('visualization', '1.0', {packages: ['corechart'], callback: draw_c7a7044d_6b17_40f2_93aa_452a3ee09ece});\n  function draw_c7a7044d_6b17_40f2_93aa_452a3ee09ece() {\n    var data_table = new google.visualization.DataTable();data_table.addColumn({\"type\":\"string\",\"label\":\"Pac Man\"});data_table.addColumn({\"type\":\"number\",\"label\":\"Percentage\"});data_table.addRow([{v: \"\"}, {v: 75}]);data_table.addRow([{v: \"\"}, {v: 25}]);\n    var chart = new google.visualization.PieChart(document.getElementById('c7a7044d-6b17-40f2-93aa-452a3ee09ece'));\n    chart.draw(data_table, {});\n  };\n</script>\n"

# %%
opts = {
  legend: 'none',
          pieSliceText: 'none',
          pieStartAngle: 135,
          tooltip: { trigger: 'none' },
          slices: {
            0 => { color: 'yellow' },
            1 => { color: 'transparent' }
          },
  type: :pie
  }
pie_pac_chart = Daru::View::Plot.new(df_pac_man, opts)
pie_pac_chart.show_in_iruby
# Out:
# "<div id='a96c3887-0117-4922-9a9b-d7045610851f'></div>\n<script>\n\n  google.load('visualization', '1.0', {packages: ['corechart'], callback: draw_a96c3887_0117_4922_9a9b_d7045610851f});\n  function draw_a96c3887_0117_4922_9a9b_d7045610851f() {\n    var data_table = new google.visualization.DataTable();data_table.addColumn({\"type\":\"string\",\"label\":\"Pac Man\"});data_table.addColumn({\"type\":\"number\",\"label\":\"Percentage\"});data_table.addRow([{v: \"\"}, {v: 75}]);data_table.addRow([{v: \"\"}, {v: 25}]);\n    var chart = new google.visualization.PieChart(document.getElementById('a96c3887-0117-4922-9a9b-d7045610851f'));\n    chart.draw(data_table, {legend: \"none\", pieSliceText: \"none\", pieStartAngle: 135, tooltip: {trigger: \"none\"}, slices: {0: {color: \"yellow\"}, 1: {color: \"transparent\"}}});\n  };\n</script>\n"

# %% [markdown]
# ### Slice Visibility Threshold

# %%
idx = Daru::Index.new ['Pizza', 'Populartiy']
data_rows = [
          ['Pepperoni', 33],
        ['Hawaiian', 26],
        ['Mushroom', 22],
        ['Sausage', 10], # Below limit.
        ['Anchovies', 9] # Below limit.
  ]
df_pizza = Daru::DataFrame.rows(data_rows)
df_pizza.vectors = idx
df_pizza
# Out:
# #<Daru::DataFrame(5x2)>
#                  Pizza Populartiy
#           0  Pepperoni         33
#           1   Hawaiian         26
#           2   Mushroom         22
#           3    Sausage         10
#           4  Anchovies          9

# %%
opts = {
title: 'Popularity of Types of Pizza',
        sliceVisibilityThreshold: 0.2,
  type: :pie, height: 400
  }
pie_pizza = Daru::View::Plot.new(df_pizza, opts)
pie_pizza.show_in_iruby
# Out:
# "<div id='31527cb6-014a-48f9-904d-7acaa8f1bd2a'></div>\n<script>\n\n  google.load('visualization', '1.0', {packages: ['corechart'], callback: draw_31527cb6_014a_48f9_904d_7acaa8f1bd2a});\n  function draw_31527cb6_014a_48f9_904d_7acaa8f1bd2a() {\n    var data_table = new google.visualization.DataTable();data_table.addColumn({\"type\":\"string\",\"label\":\"Pizza\"});data_table.addColumn({\"type\":\"number\",\"label\":\"Populartiy\"});data_table.addRow([{v: \"Pepperoni\"}, {v: 33}]);data_table.addRow([{v: \"Hawaiian\"}, {v: 26}]);data_table.addRow([{v: \"Mushroom\"}, {v: 22}]);data_table.addRow([{v: \"Sausage\"}, {v: 10}]);data_table.addRow([{v: \"Anchovies\"}, {v: 9}]);\n    var chart = new google.visualization.PieChart(document.getElementById('31527cb6-014a-48f9-904d-7acaa8f1bd2a'));\n    chart.draw(data_table, {title: \"Popularity of Types of Pizza\", sliceVisibilityThreshold: 0.2, height: 400});\n  };\n</script>\n"
